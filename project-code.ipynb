# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
df = pd.read_csv('Dataset/all_kendrick_tracks.csv')

# %%
df
# Out:
#            artist_name                                    track_name  \
# 0       Kendrick Lamar                             wacced out murals
# 1       Kendrick Lamar                                   squabble up
# 2       Kendrick Lamar                             luther (with sza)
# 3       Kendrick Lamar                             man at the garden
# 4       Kendrick Lamar                         hey now (feat. dody6)
# ..                 ...                                           ...
# 300           Jay Rock                 Colors (feat. Kendrick Lamar)
# 301           The Game              The cypha (feat. Kendrick Lamar)
# 302          Baby Keem        The Hillbillies (feat. Kendrick Lamar)
# 303          Baby Keem            family ties (feat. Kendrick Lamar)
# 304  Mike WiLL Made-It  The Mantra (feat. Pharrell & Kendrick Lamar)
#
#               album_name release_date  explicit  popularity  \
# 0                    GNX   2024-11-22      True          81
# ...

# %%
df.shape
# Out:
# (305, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   artist_name        305 non-null    object
#  1   track_name         305 non-null    object
#  2   album_name         305 non-null    object
#  3   release_date       305 non-null    object
#  4   explicit           305 non-null    bool
#  5   popularity         305 non-null    int64
#  6   track_id           305 non-null    object
#  7   duration_ms        305 non-null    int64
#  8   album_artwork_url  305 non-null    object
#  9   danceability       305 non-null    float64
#  10  energy             305 non-null    float64
#  11  valence            305 non-null    float64
#  12  tempo              305 non-null    float64
#  13  loudness           305 non-null    float64
#  14  speechiness        305 non-null    float64
#  15  acousticness       305 non-null    float64
# ...

# %%
df = df.sort_values(by='release_date', ascending= False)

# %%
df
# Out:
#          artist_name                                         track_name  \
# 0     Kendrick Lamar                                  wacced out murals
# 2     Kendrick Lamar                                  luther (with sza)
# 3     Kendrick Lamar                                  man at the garden
# 4     Kendrick Lamar                              hey now (feat. dody6)
# 5     Kendrick Lamar                                       reincarnated
# ..               ...                                                ...
# 122   Kendrick Lamar                                        Barbed Wire
# 116   Kendrick Lamar                                 Ignorance Is Bliss
# 298         Jay Rock        Jay Rock feat. Kendrick Lamar & Major James
# 296        Tae Beast          El Campo Freestyle (feat. Kendrick Lamar)
# 299  Rapper Big Pooh  Nothing Less (feat. Ab Soul, Jay Rock & Kendri...
#
#                                   album_name release_date  explicit  \
# ...

# %%
df['loudness'] = df['loudness'] * -1

# %%
df
# Out:
#          artist_name                                         track_name  \
# 0     Kendrick Lamar                                  wacced out murals
# 2     Kendrick Lamar                                  luther (with sza)
# 3     Kendrick Lamar                                  man at the garden
# 4     Kendrick Lamar                              hey now (feat. dody6)
# 5     Kendrick Lamar                                       reincarnated
# ..               ...                                                ...
# 122   Kendrick Lamar                                        Barbed Wire
# 116   Kendrick Lamar                                 Ignorance Is Bliss
# 298         Jay Rock        Jay Rock feat. Kendrick Lamar & Major James
# 296        Tae Beast          El Campo Freestyle (feat. Kendrick Lamar)
# 299  Rapper Big Pooh  Nothing Less (feat. Ab Soul, Jay Rock & Kendri...
#
#                                   album_name release_date  explicit  \
# ...

# %%
df_yearly = df.groupby('release_year').agg({
    'track_id': 'count',          # number of tracks released that year
    'popularity': 'mean',         # average popularity
    'danceability': 'mean',
    'energy': 'mean',
    'valence': 'mean',
    'tempo': 'mean',
    'loudness': 'mean',
    'duration_min': 'mean',       # average duration in minutes
})

# %%
df_yearly = df_yearly.rename(columns={'track_id': 'track_count'})

# %%
df_yearly
# Out:
#               track_count  popularity  danceability    energy   valence  \
# release_year
# 2009                    1    0.000000      0.645000  0.803000  0.436000
# 2010                   15   39.600000      0.627733  0.736667  0.492333
# 2011                   41   36.951220      0.619634  0.729195  0.533756
# 2012                   36   35.250000      0.606139  0.709028  0.483094
# 2013                   26   25.923077      0.640269  0.686769  0.448496
# 2014                   15   37.933333      0.608467  0.738667  0.489600
# 2015                   35   26.285714      0.591343  0.701829  0.479514
# 2016                   24   49.041667      0.618875  0.637500  0.445208
# 2017                   28   54.142857      0.675143  0.625179  0.501750
# 2018                   29   52.620690      0.725310  0.651069  0.460379
# 2019                    7   33.857143      0.724714  0.572143  0.402286
# 2020                    3   20.666667      0.692000  0.845333  0.599667
# ...

# %%
df_album = df.groupby('album_name').agg({
    'track_id': 'count',          
    'popularity': 'mean',         
    'danceability': 'mean',
    'energy': 'mean',
    'valence': 'mean',
    'tempo': 'mean',
    'loudness': 'mean',
    'duration_min': 'mean',
    'release_year': 'first'      
})

# %%
df_album = df_album.rename(columns={'track_id': 'track_count'})

# %%
df_album
# Out:
#                                               track_count  popularity  \
# album_name
# 100 Favors                                              1    0.000000
# 1989 (Taylor's Version) [Deluxe]                        1   70.000000
# 3ChordFold                                              1   18.000000
# 90059                                                   2   44.000000
# AMERICA HAS A PROBLEM (feat. Kendrick Lamar)            1   62.000000
# ...                                                   ...         ...
# good kid, m.A.A.d city (Deluxe)                        17   55.705882
# i                                                       1   67.000000
# meet the grahams                                        1   71.000000
# untitled 07 | levitate                                  1   49.000000
# untitled unmastered.                                    8   55.375000
#
#                                               danceability    energy  \
# album_name
# ...

# %%
df_album = df_album.sort_values(by='release_year', ascending= False)

# %%
df_album
# Out:
#                                          track_count  popularity  \
# album_name
# Not Like Us                                        1   88.000000
# euphoria                                           1   78.000000
# meet the grahams                                   1   71.000000
# WE DON'T TRUST YOU                                 1   83.000000
# GNX                                               12   78.583333
# ...                                              ...         ...
# Overly Dedicated                                  12   47.916667
# Tae Beast Tape 1                                   1    1.000000
# From Hood Tales to the Cover of XXL                1    0.000000
# We Run L.A.                                        1   18.000000
# Delightful Bars: Apple Turnover Version            1    0.000000
#
#                                          danceability    energy   valence  \
# album_name
# Not Like Us                                  0.898000  0.472000  0.214000
# ...

# %%
df_album_count = df_album.sort_values('track_count', ascending=False).head(20)

# %%
plt.figure(figsize=(10, 10))
plt.bar(df_album_count.index, df_album_count['track_count'])
plt.xticks(rotation=90)
plt.ylabel("Number of Tracks")
plt.title("Highest Tracks Per Album")
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_yearly.index, df_yearly['popularity'], marker='o')
plt.xlabel("Release Year")
plt.ylabel("Average Popularity")
plt.title("Average Popularity Over the Years")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_yearly.index, df_yearly['track_count'], marker='o')
plt.xlabel("Release Year")
plt.ylabel("Track Count")
plt.title("Tracks Released Over the Years")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.plot(df_yearly.index, df_yearly['energy'], label='Tempo', marker='o')
plt.plot(df_yearly.index, df_yearly['danceability'], label='Tempo', marker='o')
plt.plot(df_yearly.index, df_yearly['valence'], label='Valence', marker='o')

plt.xlabel("Release Year")
plt.ylabel("Value")
plt.title("Audio Attributes Over Years")
plt.legend()  
plt.grid(True)

plt.show()

# %% [markdown]
# ML - PART

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
X = df_yearly.index.values.reshape(-1, 1)  
y = df_yearly['popularity'].values

# %%
lin_model = LinearRegression()
lin_model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Cell 4: Predict future popularity for next 3 years
last_year = df_yearly.index.max()
future_years = np.array([last_year + 1, last_year + 2, last_year + 3]).reshape(-1, 1)

future_predictions = lin_model.predict(future_years)

future_df = pd.DataFrame({
    "year": future_years.flatten(),
    "predicted_popularity": future_predictions
})

future_df
# Out:
#    year  predicted_popularity
# 0  2025             64.414109
# 1  2026             67.131873
# 2  2027             69.849636

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

plt.plot(df_yearly.index, df_yearly['popularity'], marker='o', label='Historical Popularity')

x_all = np.arange(df_yearly.index.min(), last_year + 4).reshape(-1, 1)
y_all_pred = lin_model.predict(x_all)
plt.plot(x_all, y_all_pred, label="Trend")


plt.title("kendrick Lamar Popularity Trend")
plt.xlabel("Year")
plt.ylabel("Popularity")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

plt.plot(df_yearly.index, df_yearly['popularity'], marker='o', label='Historical Popularity')

x_all = np.arange(df_yearly.index.min(), last_year + 4).reshape(-1, 1)
y_all_pred = lin_model.predict(x_all)

plt.scatter(future_df['year'], future_df['predicted_popularity'],
            color='orange', label="Future Predictions")

plt.title("Results Linear Regression")
plt.xlabel("Year")
plt.ylabel("Popularity")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))

x_historical = df_yearly.index.values
x_future = future_df['year'].values
x_combined = np.concatenate([x_historical, x_future])

y_historical = df_yearly['popularity'].values
y_future = future_df['predicted_popularity'].values
y_combined = np.concatenate([y_historical, y_future])

plt.plot(x_combined, y_combined, marker='o')


plt.title("Final Popularity Forecast")
plt.xlabel("Year")
plt.ylabel("Popularity")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ML - PART XGBOOST

# %%
from xgboost import XGBRegressor

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
import matplotlib.pyplot as plt

df_ts = df_yearly.copy()

# ------------------------------------------------
# CREATE LAGS + ROLLING FEATURES
# ------------------------------------------------
df_ts['popularity_lag1'] = df_ts['popularity'].shift(1)
df_ts['popularity_lag2'] = df_ts['popularity'].shift(2)

df_ts['energy_lag1'] = df_ts['energy'].shift(1)
df_ts['danceability_lag1'] = df_ts['danceability'].shift(1)

df_ts['popularity_roll3'] = df_ts['popularity'].rolling(3).mean()

# Drop NA rows
df_ts = df_ts.dropna()

# ------------------------------------------------
# SELECT EXACT FEATURES FOR XGBOOST
# ------------------------------------------------
feature_cols = [
    'track_count',
    'danceability', 'energy', 'valence', 'tempo', 'loudness',
    'duration_min',
    'popularity_lag1', 'popularity_lag2',
    'energy_lag1', 'danceability_lag1',
    'popularity_roll3',
    'year'  # add year at the end
]

# Add year column
df_ts['year'] = df_ts.index

X = df_ts[feature_cols]
y = df_ts['popularity']

# ------------------------------------------------
# TRAIN MODEL
# ------------------------------------------------
model = XGBRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=3,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='reg:squarederror'
)

model.fit(X, y)

# ------------------------------------------------
# FORECAST NEXT 3 YEARS USING AUTO-REGRESSIVE LOOP
# ------------------------------------------------
future_years = [df_ts.index.max() + 1,
                df_ts.index.max() + 2,
                df_ts.index.max() + 3]

future_preds = []

last_row = df_ts.iloc[-1].copy()

for year in future_years:

    # Build row with EXACT SAME COLUMNS
    row = pd.DataFrame([{
        'track_count': last_row['track_count'],
        'danceability': last_row['danceability'],
        'energy': last_row['energy'],
        'valence': last_row['valence'],
        'tempo': last_row['tempo'],
        'loudness': last_row['loudness'],
        'duration_min': last_row['duration_min'],
        'popularity_lag1': last_row['popularity_lag1'],
        'popularity_lag2': last_row['popularity_lag2'],
        'energy_lag1': last_row['energy_lag1'],
        'danceability_lag1': last_row['danceability_lag1'],
        'popularity_roll3': last_row['popularity_roll3'],
        'year': year
    }])

    pred = model.predict(row)[0]
    future_preds.append(pred)

    # --- UPDATE LAGS FOR NEXT ITERATION ---
    last_row['popularity_lag2'] = last_row['popularity_lag1']
    last_row['popularity_lag1'] = pred

    last_row['popularity_roll3'] = np.mean([
        last_row['popularity_lag1'],
        last_row['popularity_lag2'],
        df_ts['popularity'].iloc[-1]  # safe fallback
    ])

# Create future dataframe
future_df = pd.DataFrame({
    "year": future_years,
    "predicted_popularity": future_preds
})

print(future_df)

# ------------------------------------------------
# PLOT RESULT
# ------------------------------------------------
plt.figure(figsize=(10,5))

plt.plot(df_yearly.index, df_yearly['popularity'], marker='o', label='Historical')
plt.plot(X['year'], model.predict(X), label='XGBoost Fit')

plt.scatter(future_df['year'], future_df['predicted_popularity'],
            color='orange', marker='o', label='Future Forecast')

plt.title("Kendrick Popularity Forecast (XGBoost with Lag Features)")
plt.xlabel("Year")
plt.ylabel("Popularity")
plt.grid(True)
plt.legend()
plt.show()
# Out:
#    year  predicted_popularity
# 0  2025             78.870758
# 1  2026             78.870758
# 2  2027             78.870758

# %% [markdown]
# ML -Part ARIMA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pmdarima import auto_arima
from statsmodels.tsa.arima.model import ARIMA

# -------------------------
# 1. Prepare the Data
# -------------------------

# If df_yearly already exists, use it. Otherwise:
# df_yearly = df.groupby('release_year')['popularity'].mean().reset_index()

df_arima = df_yearly[['release_year', 'popularity']].copy()
df_arima = df_arima.rename(columns={'release_year': 'year'})
df_arima = df_arima.set_index('year')

# Convert index to int and then to a proper datetime index
df_arima.index = pd.to_datetime(df_arima.index, format='%Y')

# -------------------------
# 2. Fit ARIMA Model
# -------------------------

# auto_arima tries to find the best (p,d,q)
model_auto = auto_arima(
    df_arima['popularity'],
    seasonal=False,
    trace=True,
    suppress_warnings=True,
    stepwise=True
)

print("\nBest ARIMA order:", model_auto.order)

# Fit the final model
model = ARIMA(df_arima['popularity'], order=model_auto.order)
model_fit = model.fit()

print(model_fit.summary())

# -------------------------
# 3. Forecast next 3 years
# -------------------------

n_years = 3
forecast = model_fit.forecast(steps=n_years)

# Build forecast dataframe
future_years = pd.date_range(
    start=df_arima.index.max() + pd.offsets.YearBegin(),
    periods=n_years,
    freq='YS'
)

forecast_df = pd.DataFrame({
    'year': future_years.year,
    'predicted_popularity': forecast.values
})

print("\nForecast:")
print(forecast_df)

# -------------------------
# 4. Plot
# -------------------------

plt.figure(figsize=(10,5))
plt.plot(df_arima.index.year, df_arima['popularity'], label='Historical')
plt.plot(forecast_df['year'], forecast_df['predicted_popularity'],
         marker='o', linestyle='--', label='Forecast')
plt.xlabel("Year")
plt.ylabel("Popularity")
plt.title("ARIMA Forecast of Popularity")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[200], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from pmdarima import auto_arima
#       5 from statsmodels.tsa.arima.model import ARIMA
#       7 # -------------------------
#       8 # 1. Prepare the Data
#       9 # -------------------------
#      10
#      11 # If df_yearly already exists, use it. Otherwise:
#      12 # df_yearly = df.groupby('release_year')['popularity'].mean().reset_index()
#
# File c:\Users\umarn\anaconda3\envs\FYP\Lib\site-packages\pmdarima\__init__.py:45
#      42 from . import __check_build
#      44 # Stuff we want at top-level
# ---> 45 from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      46 from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      47     tsdisplay
# ...

# %% [markdown]
# ML -PART ARIMA

# %%
# Install (uncomment if needed)
# !pip install statsmodels

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# -----------------------
# Prepare the series
# -----------------------
# Expect df_yearly to exist and have index = years and a 'popularity' column
# If your df_yearly is a DataFrame with index as year (int) and column 'popularity', we're good.
# Example:
# df_yearly.head()

series = df_yearly['popularity'].copy()
# convert index to datetime for plotting + model compatibility
series.index = pd.to_datetime(series.index.astype(int).astype(str), format='%Y')

# -----------------------
# Optional: small model selection by AIC (safe for very short series)
# -----------------------
# Try a few combinations and pick the best AIC. This is optional — skip or use only one model if preferred.
candidates = []
for trend in [None, 'add', 'mul']:
    for damped in [False, True]:
        if trend is None and damped:
            # can't use damped when there's no trend
            continue
        try:
            m = ExponentialSmoothing(series, trend=trend, damped_trend=damped,
                                     seasonal=None, initialization_method='estimated')
            fit = m.fit(optimized=True)
            candidates.append((trend, damped, fit.aic, fit))
        except Exception as e:
            # ignore combinations that fail (very short series can cause failures)
            pass

if len(candidates) == 0:
    raise RuntimeError("No ETS candidate could be fit on your data. Consider using a simpler model or more observations.")

# pick best by AIC
candidates = sorted(candidates, key=lambda x: x[2])
best_trend, best_damped, best_aic, best_fit = candidates[0]
print(f"Selected ETS model: trend={best_trend}, damped={best_damped}, AIC={best_aic:.2f}")

# Use the selected fit object
fit = best_fit

# -----------------------
# Optional: Holdout evaluation
# -----------------------
# If you want a quick backtest, hold out last k years (here 3)
k = 3
if len(series) > k + 1:
    train = series.iloc[:-k]
    test = series.iloc[-k:]
    # fit on train
    m2 = ExponentialSmoothing(train, trend=best_trend, damped_trend=best_damped,
                              seasonal=None, initialization_method='estimated')
    fit2 = m2.fit(optimized=True)
    pred_test = fit2.forecast(steps=k)
    rmse = np.sqrt(mean_squared_error(test, pred_test))
    print(f"HOLDOUT RMSE (last {k} years): {rmse:.3f}")
else:
    print("Skipping holdout evaluation because series is too short.")

# -----------------------
# Forecast next N years
# -----------------------
n_forecast = 3
forecast = fit.forecast(steps=n_forecast)  # returns a pandas Series with datetime index

# Build a simple approximate 95% prediction interval using residual std (approximate)
resid = fit.fittedvalues - series  # in-sample residuals (aligned by index)
sigma = resid.std(ddof=0)  # population std
z = 1.96  # ~95% CI
upper = forecast + z * sigma
lower = forecast - z * sigma

# Prepare printable dataframe for forecast (years as integers)
forecast_df = pd.DataFrame({
    'year': forecast.index.year,
    'predicted_popularity': forecast.values,
    'lower_95': lower.values,
    'upper_95': upper.values
})
print("\nForecast (approx. 95% interval):")
print(forecast_df)

# -----------------------
# Plot historical + forecast + interval
# -----------------------
plt.figure(figsize=(10,5))
plt.plot(series.index.year, series.values, marker='o', label='Historical (popularity)')
# plot fitted values (in-sample fit)
plt.plot(fit.fittedvalues.index.year, fit.fittedvalues.values, label='Fitted (in-sample)', alpha=0.7)

# forecast line + points
plt.plot(forecast.index.year, forecast.values, marker='o', linestyle='--', label='Forecast')

# shaded interval
plt.fill_between(forecast.index.year, lower.values, upper.values, color='gray', alpha=0.25, label='Approx 95% CI')

plt.xlabel('Year')
plt.ylabel('Popularity')
plt.title('ETS Forecast (Exponential Smoothing) of Popularity')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Selected ETS model: trend=add, damped=False, AIC=90.12
# HOLDOUT RMSE (last 3 years): 17.491
#
# Forecast (approx. 95% interval):
#    year  predicted_popularity   lower_95   upper_95
# 0  2025             64.414096  38.897300  89.930892
# 1  2026             67.131858  41.615062  92.648654
# 2  2027             69.849621  44.332825  95.366417
